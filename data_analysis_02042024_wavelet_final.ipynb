# %% [markdown]
# # Wavelet study
# Wavelet transform can obtain a two dimensional representation of the periodic signal with simutaneous localization in time and frequency space domains.<br>
# Wavelet transform of a given signal $\chi(k)$ is defined as:
# $$w(a,b)=\sqrt{a}\int^{+\infty}_{-\infty} \chi(k)\phi(a(k-b))dk$$
# where $\phi$ is a wavelet function, and $a$ and $b$ are the scale and translation parameters, respectively.<br>
#
# Applications:
#   * The reconstruction of **radial distruction function** from noisy EXAFS signals of copper has been performed in [3] based on the wavelet Galerkin regularization(use Daubechies-type wavelet).
#   * **identification of overlapping contributions**, in particular, coming from neighboring atoms of different type of scattering events of different order such as single and multiple-scattering.
#     * Wavelet:
#       * continuous Cauchy WT wavelet[6,9-11]
#       * Morlet WT wavelet[7,12,14]
#       * FEFF-Morlet wavelet[13]
#         * take into account the scattering properties of the atoms as computed within the FEFF formalism[15] and provides better discrimination of different atoms at similar distances than the Morlet wavelet[13].

# %%
# !pip install numpy
# !pip install scipy
# !pip install matplotlib
# !pip install pywt
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.9/site-packages (1.24.3)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from scipy) (1.24.3)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# ERROR: Could not find a version that satisfies the requirement pywt (from versions: none)
# ERROR: No matching distribution found for pywt
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: xraylarch in /srv/conda/envs/notebook/lib/python3.9/site-packages (0.9.69)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (23.0)
# Requirement already satisfied: pip in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (23.1.2)
# Requirement already satisfied: pyyaml in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (6.0)
# Requirement already satisfied: toml in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (0.10.2)
# Requirement already satisfied: pytest in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (7.3.1)
# Requirement already satisfied: termcolor in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2.3.0)
# Requirement already satisfied: scipy>=1.7 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.10.1)
# Requirement already satisfied: numpy>=1.20 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.24.3)
# Requirement already satisfied: matplotlib>=3.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (3.7.1)
# Requirement already satisfied: sqlalchemy>=2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2.0.9)
# Collecting sqlalchemy-utils (from xraylarch)
#   Downloading SQLAlchemy_Utils-0.41.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=3.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (3.8.0)
# Requirement already satisfied: pillow>=8.3.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (9.4.0)
# Requirement already satisfied: imageio in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2.28.1)
# Requirement already satisfied: charset-normalizer in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (3.1.0)
# Requirement already satisfied: peakutils in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.3.4)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2.31.0)
# Requirement already satisfied: scikit-image in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (0.19.3)
# Requirement already satisfied: scikit-learn in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.2.2)
# Requirement already satisfied: asteval>=0.9.28 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (0.9.29)
# Requirement already satisfied: lmfit>=1.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.2.1)
# Requirement already satisfied: uncertainties>=3.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (3.1.7)
# Requirement already satisfied: pyshortcuts>=1.9.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.9.0)
# Requirement already satisfied: xraydb>=4.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (4.5.0)
# Requirement already satisfied: silx>=0.15.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.1.2)
# Requirement already satisfied: hdf5plugin in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (4.1.2)
# Requirement already satisfied: numdifftools in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (0.9.41)
# Requirement already satisfied: psutil in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (5.9.4)
# Requirement already satisfied: pymatgen in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2023.5.31)
# Requirement already satisfied: fabio in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2023.4.1)
# Requirement already satisfied: pyfai in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2023.5.0)
# Collecting pycifrw (from xraylarch)
#   Downloading PyCifRW-4.4.6.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.7 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (5.12.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.9/site-packages (from silx>=0.15.2->xraylarch) (67.6.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from sqlalchemy>=2.0->xraylarch) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from sqlalchemy>=2.0->xraylarch) (2.0.2)
# Requirement already satisfied: future in /srv/conda/envs/notebook/lib/python3.9/site-packages (from uncertainties>=3.1->xraylarch) (0.18.3)
# Requirement already satisfied: ply in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pycifrw->xraylarch) (3.11)
# Requirement already satisfied: numexpr in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pyfai->xraylarch) (2.8.4)
# Requirement already satisfied: monty>=3.0.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (2023.5.8)
# Requirement already satisfied: mp-api>=0.27.3 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (0.33.3)
# Requirement already satisfied: networkx>=2.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (3.1)
# Requirement already satisfied: palettable>=3.1.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (3.3.3)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (2.0.2)
# Requirement already satisfied: plotly>=4.5.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (5.14.1)
# Requirement already satisfied: pybtex in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (0.24.0)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (0.17.21)
# Requirement already satisfied: spglib>=2.0.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (2.0.2)
# Requirement already satisfied: sympy in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (1.12)
# Requirement already satisfied: tabulate in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (0.9.0)
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (4.65.0)
# Requirement already satisfied: iniconfig in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pytest->xraylarch) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pytest->xraylarch) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pytest->xraylarch) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pytest->xraylarch) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->xraylarch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->xraylarch) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->xraylarch) (2022.12.7)
# Requirement already satisfied: tifffile>=2019.7.26 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from scikit-image->xraylarch) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from scikit-image->xraylarch) (1.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from scikit-learn->xraylarch) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from scikit-learn->xraylarch) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5->xraylarch) (3.15.0)
# Requirement already satisfied: msgpack in /srv/conda/envs/notebook/lib/python3.9/site-packages (from mp-api>=0.27.3->pymatgen->xraylarch) (1.0.5)
# Requirement already satisfied: emmet-core>=0.54.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from mp-api>=0.27.3->pymatgen->xraylarch) (0.55.4)
# Requirement already satisfied: tenacity>=6.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from plotly>=4.5.0->pymatgen->xraylarch) (8.2.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->xraylarch) (1.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from ruamel.yaml>=0.17.0->pymatgen->xraylarch) (0.2.7)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas->pymatgen->xraylarch) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas->pymatgen->xraylarch) (2023.3)
# Requirement already satisfied: latexcodec>=1.0.4 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pybtex->pymatgen->xraylarch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from sympy->pymatgen->xraylarch) (1.3.0)
# Requirement already satisfied: pydantic>=1.10.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from emmet-core>=0.54.0->mp-api>=0.27.3->pymatgen->xraylarch) (1.10.8)
# Building wheels for collected packages: pycifrw
#   Building wheel for pycifrw (pyproject.toml) ... done
#   Created wheel for pycifrw: filename=PyCifRW-4.4.6-cp39-cp39-linux_x86_64.whl size=143758 sha256=52ba51cbde290b2cfca67b5dbbcb17afa9385d2c057d351aa43cad76a03918fb
#   Stored in directory: /nsls2/users/kzheng/.cache/pip/wheels/ff/28/f3/a77c43aa825d92fb57c6a3aed39e0d35e86e02a34d323d969c
# Successfully built pycifrw
# Installing collected packages: pycifrw, sqlalchemy-utils
# Successfully installed pycifrw-4.4.6 sqlalchemy-utils-0.41.1

# %%
import numpy as np
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import time
import plotly.express as px 
import pywt
from scipy.fft import fft, ifft,fftfreq,fftshift

# %%
# !pip install xraylarch
# Out:
# Requirement already satisfied: xraylarch in /srv/conda/envs/notebook/lib/python3.9/site-packages (0.9.69)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (23.0)
# Requirement already satisfied: pip in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (23.1.2)
# Requirement already satisfied: pyyaml in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (6.0)
# Requirement already satisfied: toml in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (0.10.2)
# Requirement already satisfied: pytest in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (7.3.1)
# Requirement already satisfied: termcolor in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2.3.0)
# Requirement already satisfied: scipy>=1.7 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.10.1)
# Requirement already satisfied: numpy>=1.20 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.24.3)
# Requirement already satisfied: matplotlib>=3.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (3.7.1)
# Requirement already satisfied: sqlalchemy>=2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2.0.9)
# Requirement already satisfied: sqlalchemy-utils in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (0.41.1)
# Requirement already satisfied: h5py>=3.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (3.8.0)
# Requirement already satisfied: pillow>=8.3.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (9.4.0)
# Requirement already satisfied: imageio in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2.28.1)
# Requirement already satisfied: charset-normalizer in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (3.1.0)
# Requirement already satisfied: peakutils in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.3.4)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2.31.0)
# Requirement already satisfied: scikit-image in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (0.19.3)
# Requirement already satisfied: scikit-learn in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.2.2)
# Requirement already satisfied: asteval>=0.9.28 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (0.9.29)
# Requirement already satisfied: lmfit>=1.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.2.1)
# Requirement already satisfied: uncertainties>=3.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (3.1.7)
# Requirement already satisfied: pyshortcuts>=1.9.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.9.0)
# Requirement already satisfied: xraydb>=4.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (4.5.0)
# Requirement already satisfied: silx>=0.15.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (1.1.2)
# Requirement already satisfied: hdf5plugin in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (4.1.2)
# Requirement already satisfied: numdifftools in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (0.9.41)
# Requirement already satisfied: psutil in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (5.9.4)
# Requirement already satisfied: pymatgen in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2023.5.31)
# Requirement already satisfied: fabio in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2023.4.1)
# Requirement already satisfied: pyfai in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (2023.5.0)
# Requirement already satisfied: pycifrw in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xraylarch) (4.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib>=3.5->xraylarch) (5.12.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.9/site-packages (from silx>=0.15.2->xraylarch) (67.6.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from sqlalchemy>=2.0->xraylarch) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from sqlalchemy>=2.0->xraylarch) (2.0.2)
# Requirement already satisfied: future in /srv/conda/envs/notebook/lib/python3.9/site-packages (from uncertainties>=3.1->xraylarch) (0.18.3)
# Requirement already satisfied: ply in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pycifrw->xraylarch) (3.11)
# Requirement already satisfied: numexpr in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pyfai->xraylarch) (2.8.4)
# Requirement already satisfied: monty>=3.0.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (2023.5.8)
# Requirement already satisfied: mp-api>=0.27.3 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (0.33.3)
# Requirement already satisfied: networkx>=2.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (3.1)
# Requirement already satisfied: palettable>=3.1.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (3.3.3)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (2.0.2)
# Requirement already satisfied: plotly>=4.5.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (5.14.1)
# Requirement already satisfied: pybtex in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (0.24.0)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (0.17.21)
# Requirement already satisfied: spglib>=2.0.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (2.0.2)
# Requirement already satisfied: sympy in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (1.12)
# Requirement already satisfied: tabulate in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (0.9.0)
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pymatgen->xraylarch) (4.65.0)
# Requirement already satisfied: iniconfig in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pytest->xraylarch) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pytest->xraylarch) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pytest->xraylarch) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pytest->xraylarch) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->xraylarch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->xraylarch) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from requests->xraylarch) (2022.12.7)
# Requirement already satisfied: tifffile>=2019.7.26 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from scikit-image->xraylarch) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from scikit-image->xraylarch) (1.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from scikit-learn->xraylarch) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from scikit-learn->xraylarch) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5->xraylarch) (3.15.0)
# Requirement already satisfied: msgpack in /srv/conda/envs/notebook/lib/python3.9/site-packages (from mp-api>=0.27.3->pymatgen->xraylarch) (1.0.5)
# Requirement already satisfied: emmet-core>=0.54.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from mp-api>=0.27.3->pymatgen->xraylarch) (0.55.4)
# Requirement already satisfied: tenacity>=6.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from plotly>=4.5.0->pymatgen->xraylarch) (8.2.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->xraylarch) (1.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from ruamel.yaml>=0.17.0->pymatgen->xraylarch) (0.2.7)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas->pymatgen->xraylarch) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas->pymatgen->xraylarch) (2023.3)
# Requirement already satisfied: latexcodec>=1.0.4 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pybtex->pymatgen->xraylarch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from sympy->pymatgen->xraylarch) (1.3.0)
# Requirement already satisfied: pydantic>=1.10.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from emmet-core>=0.54.0->mp-api>=0.27.3->pymatgen->xraylarch) (1.10.8)

# %%
# %matplotlib widget

# %% [markdown]
# # Beginning: decomposation of a signal
# $$\chi(x)=sin(4x)e^{-(x-5)^2}sin(8x)e^{-(x-10)^2}$$

# %%
x=2*np.pi*np.arange(0,16,0.01)
chi1=np.sin(4*x)*np.exp(-(x-5)**2)+np.sin(8*x)*np.exp(-(x-10)**2)
f_f=fft(chi1,1600)

f_f_freq=fftfreq(len(chi1),d=0.01)
f_f_freq= fftshift(f_f_freq)

yplot = fftshift(f_f)

fig=plt.figure(figsize=(10,6))
ax1=fig.add_subplot(2,2,1)
ax1.plot(x,chi1)
ax1.set_xlim(0,16)
ax1.set_xlabel('t')

ax2=fig.add_subplot(2,2,3)
ax2.plot(f_f_freq/2,np.abs(yplot)*1/len(x))
ax2.set_xlabel('$\omega$/2')
#ax[1].set_ylim([0.01,1])
ax2.set_xlim([0.01,6])

ax3=fig.add_subplot(1,2,2)
freq=f_f_freq
freq=f_f_freq[(f_f_freq<10)&(f_f_freq>0)]
indices=np.where((f_f_freq<10)&(f_f_freq>0))
A=np.real(yplot)
A=A[indices]
print(len(A))
num=0
f_series=np.zeros(len(x))
for i in range(0,len(freq)):
    f_series+=(A[i]/len(x))*np.cos(freq[i]*x)
    if i%20==0:
        ax3.plot(x,f_series+0.5*num)
        ax3.text(12.5,0.5*num+0.05,f'{num*20} terms')
        num+=1
#ax3.plot(x,np.cos(freq[0]*x))
ax3.set_xlim(0,16)
ax3.set_ylim(-0.1,4)
ax3.set_xlabel('t')
fig.tight_layout()
# Out:
# 159
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 1. Some mother wavelets

# %% [markdown]
# ### 1.1 Morlet wavelet

# %% [markdown]
# $\phi(t)=exp(i\omega_0t)exp(-\sigma^2_0t^2)$ in paper[1].<br>
# $\sigma_0$ equals always to 1 $\AA$<br>
# * The Morlet wavelet in the pywavelets package:
#    - Morlet wavelet<br>
#     $$\phi(t) = e^{-\frac{t^2}{2}}cos(5t)$$
#    - Complex Morlet Wavelet<br>
#    $$\phi(t) = \frac{1}{\sqrt{\pi B}}exp^{-\frac{t^2}{B}}exp^{i2\pi Ct}$$
#    where B is the **Bandwidth**, C is the **center frequency**.
#
# **<span style="color:yellow">remember always a</span> $\color{yellow}{2\pi}$ <span style="color:yellow">in the cosine, sine function, so we need to sample with</span> $\color{yellow}{2\pi.}$**

# %%
fig=plt.figure(figsize=(10,8))
x=np.linspace(-8,8,1000)
wav=pywt.ContinuousWavelet('cmor1-1')
[phi, x]=wav.wavefun(level=10)
ax=fig.add_subplot(231)
ax.plot(x,np.real(phi))
ax.plot(x,np.cos(2*np.pi*x))
ax.set_xlabel("t")
ax.set_xlim(-2.5,2.5)
ax.set_title('Morlet wavelet B=1,C=1')

f_f=fft(phi,len(x))
sampling_ratio=x[3]-x[2]
f_f_freq=fftfreq(len(x),sampling_ratio)
print(len(f_f_freq))
ax=fig.add_subplot(234)
ax.plot(f_f_freq,np.abs(f_f)*1/len(x))
ax.vlines(1,0,0.0643,linestyles='dashed',label='center frequency')
ax.set_xlabel('$\omega$')
ax.set_xlim(0,2)
ax.set_ylim(0,0.08)
plt.tight_layout()
# len(wav.wavefun(level=10)[1])
print(f"Sampling rate:{x[3]-x[2]}.")


wav=pywt.ContinuousWavelet('cmor1-2')
[phi, x]=wav.wavefun(level=10)
ax=fig.add_subplot(232)
ax.plot(x,np.real(phi))
ax.plot(x,np.cos(2*np.pi*2*x))
ax.set_xlabel("t")
ax.set_xlim(-2.5,2.5)
ax.set_title('Morlet wavelet B=1,C=2')

f_f=fft(phi,len(x))
sampling_ratio=x[3]-x[2]
f_f_freq=fftfreq(len(x),sampling_ratio)
print(len(f_f_freq))
ax=fig.add_subplot(235)
ax.plot(f_f_freq,np.abs(f_f)*1/len(x))
ax.vlines(2,0,0.0643,linestyles='dashed',label='center frequency')
ax.set_xlabel('$\omega$')
ax.set_xlim(1,3)
ax.set_ylim(0,0.08)
plt.tight_layout()
# len(wav.wavefun(level=10)[1])
print(f"Sampling rate:{x[3]-x[2]}.")



wav=pywt.ContinuousWavelet('cmor1-3')
[phi, x]=wav.wavefun(level=10)
ax=fig.add_subplot(233)
ax.plot(x,np.real(phi))
ax.plot(x,np.cos(2*3*np.pi*x))
ax.set_xlabel("t")
ax.set_xlim(-3,3)
ax.set_title('Morlet wavelet B=1,C=3')

f_f=fft(phi,len(x))
sampling_ratio=x[3]-x[2]
f_f_freq=fftfreq(len(x),sampling_ratio)
print(len(f_f_freq))
ax=fig.add_subplot(236)
ax.plot(f_f_freq,np.abs(f_f)*1/len(x))
ax.vlines(3,0,0.0643,linestyles='dashed',label='center frequency')
ax.set_xlabel('$\omega$')
ax.set_xlim(2,4)
ax.set_ylim(0,0.08)
plt.tight_layout()
# len(wav.wavefun(level=10)[1])
print(f"Sampling rate:{x[3]-x[2]}.")
# Out:
# 1024
# Sampling rate:0.01564027370478982.
# 1024
# Sampling rate:0.01564027370478982.
# 1024
# D:\Users\Kaife\Temp\ipykernel_35184\3214917781.py:46: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# D:\Users\Kaife\Temp\ipykernel_35184\3214917781.py:71: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# Sampling rate:0.01564027370478982.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
half_height=0.062/2
fig=plt.figure(figsize=(10,8))
x=np.linspace(-8,8,1000)
wav=pywt.ContinuousWavelet('cmor1-1')
[phi, x]=wav.wavefun(level=10)
ax=fig.add_subplot(231)
ax.plot(x,np.real(phi))
ax.plot(x,np.cos(2*np.pi*x))
ax.set_xlabel("t")
ax.set_xlim(-2.5,2.5)
ax.set_title('Morlet wavelet B=1,C=1')

f_f=fft(phi,len(x))
sampling_ratio=x[3]-x[2]
f_f_freq=fftfreq(len(x),sampling_ratio)
half_height=np.max(np.abs(f_f)*1/len(x))/2
print(len(f_f_freq))
ax=fig.add_subplot(234)
ax.plot(f_f_freq,np.abs(f_f)*1/len(x))
ax.vlines(1,0,0.0643,linestyles='dashed',label='center frequency')
ax.set_xlabel('$\omega$')
ax.set_xlim(0,2)
ax.set_ylim(0,0.08)
plt.tight_layout()
# len(wav.wavefun(level=10)[1])
print(f"Sampling rate:{x[3]-x[2]}.")


wav=pywt.ContinuousWavelet('cmor2-1')
[phi, x]=wav.wavefun(level=10)
ax=fig.add_subplot(232)
ax.plot(x,np.real(phi))
ax.plot(x,np.cos(2*np.pi*x))
ax.set_xlabel("t")
ax.set_xlim(-3,3)
ax.set_title('Morlet wavelet B=2,C=1')

f_f=fft(phi,len(x))
sampling_ratio=x[3]-x[2]
f_f_freq=fftfreq(len(x),sampling_ratio)
print(len(f_f_freq))
ax=fig.add_subplot(235)
ax.plot(f_f_freq,np.abs(f_f)*1/len(x))
ax.vlines(1,0,0.0643,linestyles='dashed',label='center frequency')

ax.set_xlabel('$\omega$')
ax.set_xlim(0,2)
ax.set_ylim(0,0.08)
plt.tight_layout()
# len(wav.wavefun(level=10)[1])
print(f"Sampling rate:{x[3]-x[2]}.")



wav=pywt.ContinuousWavelet('cmor3-1')
[phi, x]=wav.wavefun(level=10)
ax=fig.add_subplot(233)
ax.plot(x,np.real(phi))
ax.plot(x,np.cos(2*np.pi*x))
ax.set_xlabel("t")
ax.set_xlim(-4,4)
ax.set_title('Morlet wavelet B=3,C=1')

f_f=fft(phi,len(x))
sampling_ratio=x[3]-x[2]
f_f_freq=fftfreq(len(x),sampling_ratio)
print(len(f_f_freq))
ax=fig.add_subplot(236)
ax.plot(f_f_freq,np.abs(f_f)*1/len(x))
ax.vlines(1,0,0.0643,linestyles='dashed',label='center frequency')
ax.set_xlabel('$\omega$')
ax.set_xlim(0,2)
ax.set_ylim(0,0.08)
plt.tight_layout()
# len(wav.wavefun(level=10)[1])
print(f"Sampling rate:{x[3]-x[2]}.")

index=np.where(np.round(np.real(f_f),3)!=0)
real_freq=f_f_freq[index]
bandwidth=real_freq[-1]-real_freq[0]
print(f'cmor3-1 bandwidth:{bandwidth}')
index_x=np.where((np.round(np.real(phi),3)!=0)&(np.round(np.real(phi),3)>0))
real_x=x[index_x]
bandwidth_x=real_x[-1]-real_x[0]
print(f'cmor3-1 bandwidth:{bandwidth_x}')
# Out:
# 1024
# Sampling rate:0.01564027370478982.
# 1024
# Sampling rate:0.01564027370478982.
# 1024
# D:\Users\Kaife\Temp\ipykernel_35184\3384081705.py:49: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# D:\Users\Kaife\Temp\ipykernel_35184\3384081705.py:74: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# Sampling rate:0.01564027370478982.
# cmor3-1 bandwidth:1.2487792968750009
# cmor3-1 bandwidth:8.304985337243401
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
wav=pywt.ContinuousWavelet('cmor1-1')
print("Continuous wavelet will be evaluated over the range [{}, {}]".format(
    wav.lower_bound, wav.upper_bound))

width = wav.upper_bound - wav.lower_bound

scales = [1, 2, 3, 4, 10, 30]

max_len = int(np.max(scales)*width + 1)
t = np.arange(max_len)
fig, axes = plt.subplots(len(scales), 2, figsize=(12, 6))
for n, scale in enumerate(scales):
    # The following code is adapted from the internals of cwt
    int_psi, x = pywt.integrate_wavelet(wav, precision=10)
    step = x[1] - x[0]
    j = np.floor(
        np.arange(scale * width + 1) / (scale * step))
    if np.max(j) >= np.size(int_psi):
        j = np.delete(j, np.where((j >= np.size(int_psi)))[0])
    j = j.astype(np.int_)

    # normalize int_psi for easier plotting
    int_psi /= np.abs(int_psi).max()

    # discrete samples of the integrated wavelet
    filt = int_psi[j][::-1]

    # The CWT consists of convolution of filt with the signal at this scale
    # Here we plot this discrete convolution kernel at each scale.

    nt = len(filt)
    t = np.linspace(-nt//2, nt//2, nt)
    axes[n, 0].plot(t, filt.real, t, filt.imag)
    axes[n, 0].set_xlim([-max_len//2, max_len//2])
    axes[n, 0].set_ylim([-1, 1])
    axes[n, 0].text(50, 0.35, 'scale = {}'.format(scale))

    f = np.linspace(-np.pi, np.pi, max_len)
    filt_fft = np.fft.fftshift(np.fft.fft(filt, n=max_len))
    filt_fft /= np.abs(filt_fft).max()
    axes[n, 1].plot(f, np.abs(filt_fft)**2)
    axes[n, 1].set_xlim([-np.pi, np.pi])
    axes[n, 1].set_ylim([0, 1])
    axes[n, 1].set_xticks([-np.pi, 0, np.pi])
    axes[n, 1].set_xticklabels([r'$-\pi$', '0', r'$\pi$'])
    axes[n, 1].grid(True, axis='x')
    axes[n, 1].text(np.pi/2, 0.5, 'scale = {}'.format(scale))

axes[n, 0].set_xlabel('time (samples)')
axes[n, 1].set_xlabel('frequency (radians)')
axes[0, 0].legend(['real', 'imaginary'], loc='upper left')
axes[0, 1].legend(['Power'], loc='upper left')
axes[0, 0].set_title('filter')
axes[0, 1].set_title(r'|FFT(filter)|$^2$')
# plt.tight_layout()
# Out:
# Continuous wavelet will be evaluated over the range [-8.0, 8.0]
# Text(0.5, 1.0, '|FFT(filter)|$^2$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
len(chi1)
# Out:
# 1600

# %%
wav=pywt.ContinuousWavelet('cmor6-1')
print("Continuous wavelet will be evaluated over the range [{}, {}]".format(
    wav.lower_bound, wav.upper_bound))
# Out:
# Continuous wavelet will be evaluated over the range [-8.0, 8.0]

# %% [markdown]
# ## 1.2 One example of Fourier transform and wavelet transform
# <ins>**Function**</ins>:
# $$\chi(x)=sin(4x)e^{-(x-5)^2}sin(8x)e^{-(x-10)^2}$$

# %%
from scipy.fft import fft, ifft,fftfreq,fftshift
x=2*np.pi*np.arange(0,16,0.01)
chi1=np.sin(4*x)*np.exp(-(x-5)**2)+np.sin(8*x)*np.exp(-(x-10)**2)
f_f=fft(chi1,1600)

f_f_freq=fftfreq(len(chi1),d=0.01)
f_f_freq= fftshift(f_f_freq)
yplot = fftshift(f_f)
fig,ax=plt.subplots(3,1,figsize=(8,6))
ax[1].plot(f_f_freq/2,np.abs(yplot)*1/len(x))
ax[1].set_xlabel('$\omega$/2')
#ax[1].set_ylim([0.01,1])
ax[1].set_xlim([0.01,6])
ax[0].plot(x,chi1)
ax[0].set_xlim(0,16)
ax[0].set_xlabel('x')
f_f_back=ifft(f_f)
ax[2].plot(x,f_f_back,'r',label="Inverse Fourier Transform")
ax[2].plot(x,chi1+1,'b',label="Original Signal")
ax[2].set_ylim(-1,2)
ax[2].set_xlim(0,16)
ax[2].legend(frameon=False)
ax[2].set_xlabel('t')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\kaife\anaconda3\envs\NN_work\lib\site-packages\matplotlib\cbook\__init__.py:1340: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#super simple case: A sin function
from scipy.fft import fft, ifft,fftfreq,fftshift
x=2*np.pi*np.arange(-100,100,0.001)
chi1=np.sin(x)
f_f=fft(chi1)

f_f_freq=fftfreq(len(chi1),d=0.001)
f_f_freq= fftshift(f_f_freq)
yplot = fftshift(f_f)
fig,ax=plt.subplots(3,1,figsize=(8,6))
ax[1].plot(f_f_freq,np.abs(yplot)*1/len(x))
ax[1].set_xlabel('$\omega$')
#ax[1].set_ylim([0.01,1])
ax[1].set_xlim([0,2])
ax[0].plot(x,chi1)
ax[0].set_xlabel('t')
ax[0].set_xlim(-2*np.pi,2*np.pi)
ax[0].set_xticks([-2*np.pi,-np.pi,0,np.pi,2*np.pi],['$-2\pi$','$-\pi$','0','$\pi$','$2\pi$'])
f_f_back=ifft(f_f)
ax[2].plot(x,f_f_back,'r',label="Inverse Fourier Transform")
ax[2].plot(x,chi1+1,'b',label="Original Signal")
ax[2].set_ylim(-1,2)
ax[2].set_xlim(-2*np.pi,2*np.pi)
ax[2].set_xticks([-2*np.pi,-np.pi,0,np.pi,2*np.pi],['$-2\pi$','$-\pi$','0','$\pi$','$2\pi$'])
ax[2].legend(frameon=False)
ax[2].set_xlabel('t')
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.pi/2
# Out:
# 1.5707963267948966

# %%
fig, ax = plt.subplots(2,2, figsize=(8,8), gridspec_kw={'width_ratios': [1, 4],'height_ratios': [4, 1]})
x=2*np.pi*np.arange(-2,2,0.01)

chi1=np.sin(4*x)*np.exp(-x**2/100)
#fourier transform
f_f=fft(chi1)
f_f_freq=fftfreq(len(chi1),d=0.01)
f_f_freq= fftshift(f_f_freq)
yplot = fftshift(f_f)
#wavelet transform
coef,freqs = pywt.cwt(chi1,np.arange(1,1000), 'cmor0.05-2',method='conv',sampling_period=0.01)

X, Y =np.meshgrid(x,freqs)
coef=np.abs(coef)
ax[0,1].contourf(X, Y,coef,cmap='jet',levels=100, vmax=coef.max(), vmin=-coef.min())#,vmin=a0bs(coef).min(),vmax=abs(coef).max())
ax[0,1].set_ylim(0.4,8)
ax[0,1].set_xlim(-4*np.pi,4*np.pi)
ax[0,0].plot(np.abs(yplot)*1/len(x),f_f_freq, label='FFT')
# ax[0,0].plot(np.abs(f_f),f_f_freq)
#ax[0,0].set_xlim(0,0.008)
#ax[0,0].set_ylim(0.01,6)
ax[0,0].invert_xaxis()
ax[0,0].set_ylabel('$\omega$')
ax[0,0].sharey(ax[0,1])
ax[1,1].plot(x,chi1)
ax[1,1].set_xlabel('k')
ax[1,1].sharex(ax[0,1])

#change the subplot to axR
ax[1,0].remove()
plt.show()

#axR = ax.twinx()
#axR.plot(x,chi1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f1 = pywt.scale2frequency('cmor6-0.5', 1)/0.01
f2 = pywt.scale2frequency('cmor6-0.5', 1000)/0.01
print(f1,f2)
# Out:
# 50.0 0.05

# %%
fig, ax = plt.subplots(2,2, figsize=(8,8), gridspec_kw={'width_ratios': [1, 4],'height_ratios': [4, 1]})
x=2*np.pi*np.arange(0,16,0.01)

chi1=np.sin(4*x)*np.exp(-(x-5)**2)+np.sin(8*x)*np.exp(-(x-10)**2)
#fourier transform
f_f=fft(chi1,1600)
f_f_freq=fftfreq(len(chi1),d=0.01)
f_f_freq= fftshift(f_f_freq)
yplot = fftshift(f_f)
#wavelet transform
coef,freqs = pywt.cwt(chi1,np.arange(1,1000), 'cmor5-0.5',method='conv',sampling_period=0.01)

X, Y =np.meshgrid(x,freqs)
coef=np.abs(coef)
ax[0,1].contourf(X, Y/2,coef,cmap='jet',levels=200, vmax=abs(coef).max(), vmin=-abs(coef).min())#,vmin=a0bs(coef).min(),vmax=abs(coef).max())
ax[0,1].set_ylim(0.1,6)
ax[0,1].set_xlim(0,17)
ax[0,0].plot(np.abs(yplot)*1/len(x),f_f_freq/2, label='FFT')
# ax[0,0].plot(np.abs(f_f),f_f_freq)
#ax[0,0].set_xlim(0,0.008)
#ax[0,0].set_ylim(0.01,6)
ax[0,0].invert_xaxis()
ax[0,0].set_ylabel('$\omega/2$')
ax[0,0].sharey(ax[0,1])
ax[1,1].plot(x,chi1)
ax[1,1].set_xlabel('t')
ax[1,1].sharex(ax[0,1])

#change the subplot to axR
ax[1,0].remove()
plt.show()

#axR = ax.twinx()
#axR.plot(x,chi1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(2,2, figsize=(8,8), gridspec_kw={'width_ratios': [1, 4],'height_ratios': [4, 1]})
x=2*np.pi*np.arange(0,16,0.01)

chi1=np.sin(4*x)*np.exp(-(x-5)**2)+2*np.sin(4*x)*np.exp(-(x-10)**2)
#fourier transform
f_f=fft(chi1,1600)
f_f_freq=fftfreq(len(chi1),d=0.01)
f_f_freq= fftshift(f_f_freq)
yplot = fftshift(f_f)
#wavelet transform
coef,freqs = pywt.cwt(chi1,np.arange(1,1000), 'cmor5-0.5',method='conv',sampling_period=0.01)

X, Y =np.meshgrid(x,freqs)
coef=np.abs(coef)
ax[0,1].contourf(X, Y/2,coef,cmap='jet',levels=200, vmax=abs(coef).max(), vmin=-abs(coef).min())#,vmin=a0bs(coef).min(),vmax=abs(coef).max())
ax[0,1].set_ylim(0.1,6)
ax[0,1].set_xlim(0,17)
ax[0,0].plot(np.abs(yplot)*1/len(x),f_f_freq/2, label='FFT')
# ax[0,0].plot(np.abs(f_f),f_f_freq)
#ax[0,0].set_xlim(0,0.008)
#ax[0,0].set_ylim(0.01,6)
ax[0,0].invert_xaxis()
ax[0,0].set_ylabel('$\omega/2$')
ax[0,0].sharey(ax[0,1])
ax[1,1].plot(x,chi1)
ax[1,1].set_xlabel('t')
ax[1,1].sharex(ax[0,1])

#change the subplot to axR
ax[1,0].remove()
plt.show()

#axR = ax.twinx()
#axR.plot(x,chi1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # real wavelet transform on X-ray absorption spectra

# %%
import larch
from wxmplot.interactive import plot
from larch.xafs import autobk
from larch.xafs import cauchy_wavelet
from larch.io import read_ascii,read_athena,merge_groups
from larch.xafs import find_e0,pre_edge,autobk,xftf,xftr
from larch import Group
import glob
import os
import glob,linecache,shutil
import numpy as np
import xarray as xr

from copy import deepcopy
import datetime
import json

import os
import matplotlib.pyplot as plt
import pymatgen
from pymatgen.core import Lattice, Structure
from matplotlib import rc
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from Zanes import data_analysis
from larch import Group, Journal
from larch import Make_CallArgs, parse_group_args
# def set_xafsGroup(group, _larch=None):

#     """set _sys.xafsGroup to the s<upplied group (if not None)

#     return _sys.xafsGroup.

#     if needed, a new, empty _sys.xafsGroup may be created.
#     """
#     if group is None:
#         if _larch is None:
#             group = Group()
#         else:
#             group = getattr(_larch.symtable._sys, 'xafsGroup', Group())
#     if not hasattr(group, 'journal'):
#         group.journal = Journal()

#     if _larch is not None:
#         _larch.symtable._sys.xafsGroup = group
#     return group

# def morlet_wavelet(k, chi=None, group=None, kweight=0, rmax_out=10,
#                    nfft=2048, _larch=None):
#     kstep = np.round(1000.*(k[1]-k[0]))/1000.0
#     rmin = 1.e-7
#     rmax = rmax_out
#     rstep = (np.pi/2048)/kstep
#     nrpts = int(np.round((rmax-rmin)/rstep))
#     nkout = len(k)
#     kstep = np.round(1000.*(k[1]-k[0]))/1000.0
#     if kweight != 0:
#         chi = chi * k**kweight
#     NFT = int(nfft/2)
#     if len(k) < NFT:
#         knew = np.arange(NFT) * kstep
#         xnew = np.zeros(NFT) * kstep
#         xnew[:len(k)] = chi
#     else:
#         knew = k[:NFT]
#         xnew = chi[:NFT]

#     # FT parameters
#     freq = (1.0/kstep)*np.arange(nfft)/(2*nfft)
#     omega = 2*np.fft.fft(xnew,n=2*nfft)
#     r  = np.linspace(0, rmax, nrpts)
#     coef,freqs = pywt.cwt(xnew,np.arange(1,nrpts), 'cmor5-0.5',method='conv',sampling_period=0.01)
#     coef_m=np.abs(coef)
    
#     group = set_xafsGroup(group, _larch=_larch)
#     group.wcauchy_r  =  r
#     group.wcauchy    =  freqs
#     group.wcauchy_mag = coef_m
#     group.wcauchy_re=coef.real
#     group.wcauchy_im=coef.imag

def wavelet_transform(group,kmin=0,kmax=20,rmin=0,rmax=20,kweight=0,rweight=0,dk=1,dr=0,windows='hanning',original=True):
     xftf(group.k,group.chi, kmin=kmin, kmax=kmax, dk=dk, window=windows,
          kweight=kweight, group=group)
     xftr(group.r,group.chir, rmin=rmin, rmax=rmax, dr=dr, window=windows,group=group)
     fig, ax = plt.subplots(2,2, figsize=(8,8), gridspec_kw={'width_ratios': [1, 4],'height_ratios': [4, 1]})
     k2chi=group.k*group.k*group.chi
     #morlet_wavelet(k=group.q,chi=group.chiq,group=group,kweight=0)
     if original==True:
         X, Y =np.meshgrid(group.k, group.r)
         cauchy_wavelet(k=group.k,chi=k2chi,group=group)
     else:
         X, Y =np.meshgrid(group.q, group.r)
         cauchy_wavelet(k=group.q,chi=group.chiq,group=group)
     
     kwinmax=np.max(group.kwin)
     kmax=np.max(k2chi)
     rwinmax=np.max(group.rwin)
     rmax=np.max(group.chir_mag)

     # ax[0,1].contourf(, Y/2,coef,cmap='jet',levels=200, vmax=abs(coef).max(), vmin=-abs(coef).min())#,vmin=a0bs(coef).min(),vmax=abs(coef).max())
     # plt.imshow(back_f.wcauchy_mag,label='Wavelet Transform: Magnitude')
     ax[0,1].contourf(X,Y,group.wcauchy_mag,cmap='jet',levels=200, vmax=abs(group.wcauchy_re).max(), vmin=-abs(group.wcauchy_re).min())#,vmin=a0bs(coef).min(),vmax=abs(coef).max())
     ax[0,0].plot(group.chir_mag,group.r)
     if original==False:
         ax[0,0].plot(group.rwin*rmax/rwinmax,group.r)
     # ax[0,0].invert_xaxis()
     ax[0,0].set_ylabel('r')
     ax[0,0].sharey(ax[0,1])
     ax[1,1].set_xlabel('k')
     ax[1,1].sharex(ax[0,1])
     if original==True:
         ax[1,1].plot(group.k,group.k*group.k*group.chi)
     if original==False:
         ax[1,1].plot(group.q,group.chiq)
    #  ax[1,1].plot(group.k,group.kwin*kmax/kwinmax)
     ax[0,1].set_ylim(0.1,3)
     ax[0,1].set_xlim(0,10)
     ax[1,0].remove()

# %%
def read_iss_Xpress3_multi(element='Cr',pattern='*.dat',plot='True'):
    filenames=glob.glob(pattern)
    data=[]
    if element=='Cr':
        for index, scan in enumerate(filenames):
            #scan = scan.resolve()  # Make the path absolute, resolving any symlinks
            #scanname = scan.name
            scan_data=read_ascii(scan)
            #print(scan_data.keys())
            scan_data.mu=-(scan_data.xs_roi01 / scan_data.i0)
            scan_data.label=scan.split('/')[-1].split('.')[0]
            data.append(scan_data)
    if element=='Ni' or element=='Hf':
        for index, scan in enumerate(filenames):
            #scan = scan.resolve()  # Make the path absolute, resolving any symlinks
            #scanname = scan.name
            scan_data=read_ascii(scan)
            #print(scan_data.keys())
            scan_data.mu=-(scan_data.xs_roi02 / scan_data.i0)
            scan_data.label=scan.split('/')[-1].split('.')[0]
            data.append(scan_data)
    if plot=='True':
        plt.figure()
        for d in data:
            plt.plot(d.energy,d.mu,label=d.label)
        plt.legend(frameon=False)
        plt.xlabel('Energy')
        plt.ylabel('mu')
    return data
def read_iss_Xpress3_merge(element='Cr', pattern='*.dat'):
    filenames=glob.glob(pattern)
    data=[]
    if element=='Cr':
        for index, scan in enumerate(filenames):
            #scan = scan.resolve()  # Make the path absolute, resolving any symlinks
            #scanname = scan.name
            scan_data=read_ascii(scan)
            #print(scan_data.keys())
            scan_data.mu=-(scan_data.xs_roi01 / scan_data.i0)
            data.append(scan_data)
    if element=='Ni' or element=='Hf':
        for index, scan in enumerate(filenames):
            #scan = scan.resolve()  # Make the path absolute, resolving any symlinks
            #scanname = scan.name
            scan_data=read_ascii(scan)
            #print(scan_data.keys())
            scan_data.mu=-(scan_data.xs_roi02 / scan_data.i0)
            data.append(scan_data)
        
    merged_data = merge_groups(data, master=None, xarray='energy', yarray='mu', kind='cubic', trim=True)
    merged_data.label='merged'
    return merged_data

# %%
# file_name=glob.glob("/nsls2/data/iss/legacy/processed/2024/1/312268/*.dat")
# Energy,intensity=read_iss_Xpress3(file_name[-10],'Ni')
# plt.plot(Energy,intensity)

# %%
record1=glob.glob("/nsls2/data/iss/legacy/processed/2024/1/312268/*.dat")[-50:-1]
record1
# Out:
# ['/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0001.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0002.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0003.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0004.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0005.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0006.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0007.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0008.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0009.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_500C_run2 Cu-K 0010.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0001.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0002.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0003.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0004.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0005.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0006.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0007.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0008.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0009.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0010.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0011.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0012.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0013.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0014.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_600C_run1 Cu-K 0015.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0001.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0002.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0003.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0004.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0005.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0006.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0007.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0008.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0009.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0010.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0011.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0012.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0013.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0014.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_700C_run1 Cu-K 0015.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_800C_run1 Cu-K 0001.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_800C_run1 Cu-K 0002.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_800C_run1 Cu-K 0003.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_800C_run1 Cu-K 0004.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_800C_run1 Cu-K 0005.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_800C_run1 Cu-K 0006.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_800C_run1 Cu-K 0007.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_800C_run1 Cu-K 0008.dat',
#  '/nsls2/data/iss/legacy/processed/2024/1/312268/4a_CuO_vac ramping_800C_run1 Cu-K 0009.dat']

# %%
new_group=read_iss_Xpress3_merge(element='Ni', pattern="/nsls2/data/iss/legacy/processed/2024/1/312268/3a_NaNO3-KNO3_Ni20Cr C2_cooling_run1 (pos 001) Ni-K SDD*.dat")

# %%
data_analysis.data_analysis(new_group,pre_start=-120,pre_end=-50,post_start=50,post_end=900,kweight=2,rbkg=1.5,
                  plot=True,kwin='hanning',krange=[2,8])
# Out:
# E0=8344.4

# %%
a=Group(k=new_group.k,chi=new_group.chi)
xftf(k=a.k,chi=a.chi,dk=2,kweight=2,group=a,kmin=2,kmax=10,kstep=a.k[2]-a.k[1],window="hanning")  
plt.figure()
plt.plot(a.k,a.chi)

# %%
import pandas as pd
table={"k":new_group.k,
       "chi":new_group.chi
}
pd.DataFrame(table).to_csv("k_chi.csv",index=None)

# %%
plt.figure()
plt.plot(a.r,a.chir_mag)

# %%
wavelet_transform(new_group,kmin=2,kmax=12,rmin=1,rmax=4,kweight=2,rweight=0,dk=2,dr=0,windows='hanning',original=True)

# %%
glob.glob("/nsls2/data/iss/legacy/processed/2024/1/312268/*RAMP.dat")
# Out:
# []

# %%
# plot multiple spectra

# %%
new_group=read_iss_Xpress3_merge(element='Cr', pattern="/nsls2/data/iss/legacy/processed/2024/1/312268/3a_NaNO3-KNO3_Ni20Cr C2_HT_run1 (pos 001) Cr-K_SDD*.dat")

# %%
 read_iss_Xpress3_multi(element='Cr',pattern="/nsls2/data/iss/legacy/processed/2024/1/312268/3a_NaNO3-KNO3_Ni20Cr C2_HT_run1 (pos 001) Cr-K_SDD*.dat",plot='True')
# Out:
# [<Group ascii_file /nsls2/data/iss/legacy/processed/2024/1/312268/3a_NaNO3-KNO3_Ni20Cr C2_HT_run1 (pos 001) Cr-K_SDD 0001.dat>,
#  <Group ascii_file /nsls2/data/iss/legacy/processed/2024/1/312268/3a_NaNO3-KNO3_Ni20Cr C2_HT_run1 (pos 001) Cr-K_SDD 0002.dat>,
#  <Group ascii_file /nsls2/data/iss/legacy/processed/2024/1/312268/3a_NaNO3-KNO3_Ni20Cr C2_HT_run1 (pos 001) Cr-K_SDD 0003.dat>,
#  <Group ascii_file /nsls2/data/iss/legacy/processed/2024/1/312268/3a_NaNO3-KNO3_Ni20Cr C2_HT_run1 (pos 001) Cr-K_SDD 0004.dat>,
#  <Group ascii_file /nsls2/data/iss/legacy/processed/2024/1/312268/3a_NaNO3-KNO3_Ni20Cr C2_HT_run1 (pos 001) Cr-K_SDD 0005.dat>]
